# %% [markdown]
# **Import** **Libraries**

# %% [markdown]
# **SANJYOT GAMBARE**
#
# **Data science and business** **analytics intern @TheSparksFoundation**

# %% [markdown]
# ![Screenshot (275).png](data:image/png;base64,...)

# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
import nltk
nltk.download('vader_lexicon')
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
#  **Store the Date, Time and News Headlines Data**

# %%
news_tables = {}
tickers = ['AMZN', 'TSLA', 'GOOG']

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

# %%
# Read one single day of headlines for 'AMZN' 
amzn = news_tables['AMZN']
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# Should Salesforce Investors Be Worried About Microsoft?
# May-20-21 08:30AM
# 3 High-Growth Cloud Stocks I'd Buy Right Now
# 08:03AM
# Housebuilder St Modwen confirms £1.2bn BlackStone bid
# 07:14AM
# Blockbusters like Godzilla v. Kong help all of us in the movie business: Jane Rosenthal
# 07:00AM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['AMZN',
#   'May-20-21',
#   '08:30AM',
#   'Should Salesforce Investors Be Worried About Microsoft?'],
#  ['AMZN',
#   'May-20-21',
#   '08:03AM',
#   "3 High-Growth Cloud Stocks I'd Buy Right Now"],
#  ['AMZN',
#   'May-20-21',
#   '07:14AM',
#   'Housebuilder St Modwen confirms £1.2bn BlackStone bid'],
#  ['AMZN',
#   'May-20-21',
#   '07:00AM',
#   'Blockbusters like Godzilla v. Kong help all of us in the movie business: Jane Rosenthal'],
#  ['AMZN',
#   'May-20-21',
#   '07:00AM',
#   '2 Stocks That Will Help You Survive the Stock Market Correction'],
#  ['AMZN',
#   'May-20-21',
#   '06:27AM',
#   'How to Handle Post-Earnings Drops in Your Stock Portfolio'],
#  ['AMZN', 'May-20-21', '06:15AM', 'Could Amazon Stock Still Be Undervalued?'],
#  ['AMZN',
#   'May-20-21',
#   '06:06AM',
#   '4 Stocks That Could Be Worth $1 Trillion by 2035'],
#  ['AMZN',
#   'May-20-21',
#   '06:00AM',
#   'Influencers with Andy Serwer: Jane Rosenthal'],
#  ['AMZN',
#   'May-20-21',
#   '05:47AM',
#   '10 Best Dividend Stocks to Buy According to Billionaire Richard Chilton'],
#  ['AMZN',
#   'May-19-21',
#   '08:56PM',
#   'Amazon (NASDAQ:AMZN) Is Firing On All Cylinders'],
#  ['AMZN',
#   'May-19-21',
#   '08:06PM',
#   'Amazon Sued by Five Women Alleging Bias, Retaliation'],
#  ['AMZN',
#   'May-19-21',
#   '08:00PM',
#   'The new media worlds streams lead to Amazon'],
#  ['AMZN',
#   'May-19-21',
#   '07:00PM',
#   'One Company To Watch As Electric Vehicle Stocks Get Ready To Fly This Summer'],
#  ['AMZN',
#   'May-19-21',
#   '06:54PM',
#   'Amazon.com faces five new racial, gender bias lawsuits'],
#  ['AMZN',
#   'May-19-21',
#   '04:40PM',
#   'UPDATE 1-Echoing Amazon: Walmart, Target try local package delivery'],
#  ['AMZN',
#   'May-19-21',
#   '04:38PM',
#   'The streaming space is evolving so quickly, mirroring the evolution of traditional TV: ViacomCBS Streaming President & CEO'],
#  ['AMZN', 'May-19-21', '04:36PM', 'Is Amazon hugely undervalued?'],
#  ['AMZN',
#   'May-19-21',
#   '03:54PM',
#   'Echoing Amazon: Walmart, Target try local package delivery'],
#  ['AMZN', 'May-19-21', '03:46PM', 'The revenge of the underpaid'],
#  ['AMZN',
#   'May-19-21',
#   '03:35PM',
#   "Oatly's IPO Could Fetch a $10 Billion Valuation This Week. Here's What Investors Need to Know"],
#  ['AMZN',
#   'May-19-21',
#   '03:02PM',
#   "'There clearly will be more consolidation' in streaming space as WarnerMedia, Discovery deal pressures platforms: Media executive"],
#  ['AMZN',
#   'May-19-21',
#   '02:58PM',
#   'Kellogg CEO: We are battling inflation like everybody else is'],
#  ['AMZN',
#   'May-19-21',
#   '02:31PM',
#   'Amazon Aims to Acquire MGM: Would That Hurt CRE?'],
#  ['AMZN',
#   'May-19-21',
#   '01:02PM',
#   'How to get an Amazon Echo Dot for 99 cents'],
#  ['AMZN',
#   'May-19-21',
#   '12:41PM',
#   "Amazon Halts Police's Use Of Facial Recognition Software: Reuters"],
#  ['AMZN',
#   'May-19-21',
#   '12:31PM',
#   'Is Amazon.com (AMZN) A Great Investment Choice?'],
#  ['AMZN',
#   'May-19-21',
#   '12:08PM',
#   'Is Shopify Stock A Buy After Blowout Earnings Report?'],
#  ['AMZN',
#   'May-19-21',
#   '11:00AM',
#   'Ampere Says Microsoft, Tencent Are Customers, Unveils New Design'],
#  ['AMZN',
#   'May-19-21',
#   '10:47AM',
#   '8 thoughtful gifts for high school grads, all under $25'],
#  ['AMZN',
#   'May-19-21',
#   '10:00AM',
#   'Are the FAANG Stocks Still Good Buys Today?'],
#  ['AMZN',
#   'May-19-21',
#   '09:30AM',
#   'Movie theater experience has to reinvent itself: Jane Rosenthal'],
#  ['AMZN', 'May-19-21', '08:56AM', 'Better Buy: Amazon vs. Ulta Beauty'],
#  ['AMZN',
#   'May-19-21',
#   '08:40AM',
#   'Amazon Could Acquire MGM Studios For $9B  Report'],
#  ['AMZN',
#   'May-19-21',
#   '08:30AM',
#   'Down 25% From Its IPO, Is Now the Time to Buy Coupang?'],
#  ['AMZN',
#   'May-19-21',
#   '08:25AM',
#   'Attention, Growth Stock Investors: Price Matters'],
#  ['AMZN',
#   'May-19-21',
#   '08:15AM',
#   'Down 40%, Is Now the Time to Buy Spotify Stock?'],
#  ['AMZN',
#   'May-19-21',
#   '07:38AM',
#   "From Amazon to McDonald's, here's who's hiking wages amid the labor crunch"],
#  ['AMZN',
#   'May-19-21',
#   '07:16AM',
#   'Amazon is a cheap stock for long-term investors. These numbers tell you why.'],
#  ['AMZN',
#   'May-19-21',
#   '06:51AM',
#   'Spring Market Mania: These 2 Growth Stocks Are on Sale'],
#  ['AMZN',
#   'May-19-21',
#   '05:51AM',
#   '4 Unstoppable Stocks With 34% to 51% Upside, According to Wall Street'],
#  ['AMZN',
#   'May-18-21',
#   '07:10PM',
#   'AWS Announces General Availability of AWS App Runner'],
#  ['AMZN',
#   'May-18-21',
#   '05:57PM',
#   'German Federal Cartel Office Launches Fresh Antitrust Investigation Against Amazon: Report'],
#  ['AMZN',
#   'May-18-21',
#   '05:21PM',
#   'Amazons Talks With MGM Bring Fresh Shine to Old Movie Libraries'],
#  ['AMZN',
#   'May-18-21',
#   '04:40PM',
#   "'When were really out of the pandemic, youre not going to see... hybrid releases,': IMAX CEO"],
#  ['AMZN',
#   'May-18-21',
#   '04:29PM',
#   'UPDATE 3-Amazon extends moratorium on police use of facial recognition software'],
#  ['AMZN',
#   'May-18-21',
#   '04:25PM',
#   "Amazon's Bid For MGM Escalates Major Battle To Dominate Movie Market"],
#  ['AMZN',
#   'May-18-21',
#   '04:08PM',
#   'Walmart Earnings Beat As Comp Sales Smash Forecasts'],
#  ['AMZN',
#   'May-18-21',
#   '03:28PM',
#   'Amazon Extends Pause on Police Use of Facial Recognition Tech'],
#  ['AMZN',
#   'May-18-21',
#   '03:01PM',
#   'Shopify Merchants Will Be Showcased on Googles Shopping Site'],
#  ['AMZN',
#   'May-18-21',
#   '02:18PM',
#   'Pro-tax millionaires protest outside Jeff Bezos home on Tax Day'],
#  ['AMZN',
#   'May-18-21',
#   '02:08PM',
#   'Discovery stock could be worth 35% more after AT&T deal: analyst'],
#  ['AMZN',
#   'May-18-21',
#   '01:20PM',
#   'Fears ITV will lose James Bond in $9bn Amazon swoop on MGM'],
#  ['AMZN',
#   'May-18-21',
#   '01:15PM',
#   "Why AT&T's stock is getting smashed after mega media deal with Discovery"],
#  ['AMZN',
#   'May-18-21',
#   '12:39PM',
#   'Amazon Considers Buying Movie Studio MGM for $9 Billion'],
#  ['AMZN',
#   'May-18-21',
#   '12:12PM',
#   "Redbox CEO on building a 'one-stop-shop for entertainment'"],
#  ['AMZN',
#   'May-18-21',
#   '12:03PM',
#   '3 Tech Stocks That Turned $10,000 Into Over $200,000'],
#  ['AMZN',
#   'May-18-21',
#   '11:36AM',
#   'Amazon (AMZN) to Broaden Reach in India Via MiniTV Launch'],
#  ['AMZN',
#   'May-18-21',
#   '11:28AM',
#   'Amazon shakes and stirs the streaming wars with MGM deal'],
#  ['AMZN',
#   'May-18-21',
#   '10:42AM',
#   'Apple (AAPL) Music to Add Lossless Audio, Dolby Atmos Support'],
#  ['AMZN',
#   'May-18-21',
#   '10:27AM',
#   'Amazon Prime Day 2021: When can you expect it? Is it worth the hype?'],
#  ['AMZN', 'May-18-21', '10:05AM', '10 Best Blockchain Stocks to Buy'],
#  ['AMZN',
#   'May-18-21',
#   '09:25AM',
#   'Amazon in talks to buy MGM for $9 billion: RPTS'],
#  ['AMZN',
#   'May-18-21',
#   '09:15AM',
#   "The Latest Sign Amazon Doesn't See Growth Slowing in 2021"],
#  ['AMZN',
#   'May-18-21',
#   '08:13AM',
#   'Amazon Music HD Made Available to All Subscribers at No Extra Cost; Street Says Buy'],
#  ['AMZN',
#   'May-18-21',
#   '08:09AM',
#   'Discovery-WarnerMedia Merger to Rev Up Streaming Competition'],
#  ['AMZN',
#   'May-18-21',
#   '07:30AM',
#   "Is Amazon Stock A Buy Right Now? Here's What Earnings, Charts Show"],
#  ['AMZN', 'May-18-21', '07:30AM', '1 Top Stock Under $5'],
#  ['AMZN',
#   'May-18-21',
#   '06:31AM',
#   'Which Electric Vehicle Stocks Could Produce 10X Returns?'],
#  ['AMZN', 'May-18-21', '06:30AM', 'Amazon in Talks to Buy MGM'],
#  ['AMZN', 'May-18-21', '06:15AM', '3 No-Brainer Buys When the Market Crashes'],
#  ['AMZN',
#   'May-18-21',
#   '06:06AM',
#   'Your Stock Market Crash Checklist: 10 Things to Do'],
#  ['AMZN',
#   'May-18-21',
#   '05:51AM',
#   'Dogecoin Is All Hype: Buy These Surefire Stocks Instead'],
#  ['AMZN',
#   'May-18-21',
#   '05:30AM',
#   'Walmart Has Lost Its Lead in Online Grocery'],
#  ['AMZN',
#   'May-18-21',
#   '03:48AM',
#   'Amazon in talks to buy James Bond studio MGM for $9bn'],
#  ['AMZN',
#   'May-18-21',
#   '01:15AM',
#   'Walmart, Amazon, Home Depot, Fisker, Wells Fargo - 5 Things You Must Know'],
#  ['AMZN',
#   'May-18-21',
#   '12:46AM',
#   'Amazon in Talks to Buy Film Studio MGM, Reports Say'],
#  ['AMZN',
#   'May-17-21',
#   '09:51PM',
#   'Amazon in talks to buy James Bond studio MGM'],
#  ['AMZN',
#   'May-17-21',
#   '08:55PM',
#   "Amazon's Twitch Lowering Non-U.S. Subscription Prices"],
#  ['AMZN', 'May-17-21', '08:00PM', 'Amazon in talks to buy MGM for $9bn'],
#  ['AMZN',
#   'May-17-21',
#   '07:08PM',
#   'Amazon Said to Make $9 Billion Offer for MGM'],
#  ['AMZN',
#   'May-17-21',
#   '07:07PM',
#   'Amazon Could Skyrocket 83% by 2023, Analyst Says'],
#  ['AMZN',
#   'May-17-21',
#   '06:25PM',
#   'This Transportation Stock Has Outperformed Big Tech Over the Past Decade'],
#  ['AMZN',
#   'May-17-21',
#   '05:48PM',
#   'What the WarnerMedia-Discovery mergers means for the streaming wars'],
#  ['AMZN',
#   'May-17-21',
#   '04:11PM',
#   'Amazon Mailbox Modification Is Latest Twist in Union Election'],
#  ['AMZN',
#   'May-17-21',
#   '02:39PM',
#   "Market volatility to continue through the summer: People's United Advisors CIO"],
#  ['AMZN',
#   'May-17-21',
#   '02:39PM',
#   'Amazon-Backed Tado Raises $46M In Fundraiser Before IPO: FT'],
#  ['AMZN',
#   'May-17-21',
#   '01:55PM',
#   'AT&T admits it made a terrible mistake getting into media business with Discovery deal: analyst'],
#  ['AMZN',
#   'May-17-21',
#   '01:29PM',
#   'Inflation has been the friend of stocks: Strategist'],
#  ['AMZN',
#   'May-17-21',
#   '12:36PM',
#   "Discovery with AT&T's media assets will put pressure on Netflix, others: analyst"],
#  ['AMZN',
#   'May-17-21',
#   '12:25PM',
#   "U.S. experiencing 'a marked shift in bargaining power towards lower-income workers'"],
#  ['AMZN',
#   'May-17-21',
#   '12:02PM',
#   'Apple and Amazon Boost Sound Quality of Streaming Music, Targeting Spotify'],
#  ['AMZN',
#   'May-17-21',
#   '11:36AM',
#   'Amazon, Apple not to charge extra for lossless music'],
#  ['AMZN',
#   'May-17-21',
#   '11:01AM',
#   'The 3 Smartest Stocks to Buy in a Reopening Economy'],
#  ['AMZN',
#   'May-17-21',
#   '10:05AM',
#   'Why the AT&T, Discovery deal puts the most pressure on Comcast'],
#  ['AMZN', 'May-17-21', '09:55AM', 'Where Will Walmart Be in 5 Years?'],
#  ['AMZN',
#   'May-17-21',
#   '09:53AM',
#   '10 Small-Cap Stocks With Huge Growth Potential'],
#  ['AMZN',
#   'May-17-21',
#   '09:38AM',
#   '7 best free and paid-for VPNs for streaming and security on your Android, iPhone, PC and more'],
#  ['AMZN',
#   'May-17-21',
#   '09:29AM',
#   '3 Reasons Best Buy Stock Will Likely Be Higher in 5 Years'],
#  ['AMZN',
#   'May-17-21',
#   '09:21AM',
#   'Mask mandate: These retailers will now let you shop without a mask'],
#  ['TSLA',
#   'May-20-21',
#   '08:41AM',
#   'Dogecoin jumps as Elon Musk takes to Twitter again'],
#  ['TSLA',
#   'May-20-21',
#   '08:12AM',
#   'Dow Jones Futures Fall As Stock Market Rally Test Continues, Bitcoin Rebounds; Target, Facebook, Google In Buy Zones'],
#  ['TSLA', 'May-20-21', '08:00AM', 'Better Buy: Bitcoin vs. Square'],
#  ['TSLA',
#   'May-20-21',
#   '07:52AM',
#   'Ford Stock Climbs After F-150 Lightning Electric Pickup Unveiled'],
#  ['TSLA',
#   'May-20-21',
#   '07:30AM',
#   'The Tech Sell-Off Just Sent 3 Top Stocks Down 20%-Plus'],
#  ['TSLA',
#   'May-20-21',
#   '07:13AM',
#   "Crypto Crash: Bitcoin, Ethereum, and Dogecoin Are Plunging. Here's Why."],
#  ['TSLA',
#   'May-20-21',
#   '06:45AM',
#   'Crypto price news  live: Bitcoin crash halted after Elon Musk says Tesla has diamond hands'],
#  ['TSLA',
#   'May-20-21',
#   '06:36AM',
#   'Zacks Market Edge Highlights: Shopify, PayPal, DraftKings, Exact Sciences and Tesla'],
#  ['TSLA',
#   'May-20-21',
#   '06:04AM',
#   'Ethereum to reduce emissions as cryptos face climate scrutiny'],
#  ['TSLA',
#   'May-20-21',
#   '05:51AM',
#   '700 Million Reasons the Dogecoin Bubble Will Burst'],
#  ['TSLA',
#   'May-20-21',
#   '03:52AM',
#   'Dogecoin Recovers Losses on Yet Another Elon Musk Tweet'],
#  ['TSLA',
#   'May-20-21',
#   '03:44AM',
#   'Bitcoin climbs above $40,000 as crypto market reels from sell-off'],
#  ['TSLA',
#   'May-20-21',
#   '01:11AM',
#   "UPDATE 3-Bitcoin's star backers, dip buyers help cryptos recover"],
#  ['TSLA',
#   'May-19-21',
#   '11:15PM',
#   "Bitcoin's star backers, dip buyers help cryptos recover"],
#  ['TSLA',
#   'May-19-21',
#   '11:13PM',
#   'Bitcoin struggles for footing on worries over China, leverage'],
#  ['TSLA',
#   'May-19-21',
#   '09:32PM',
#   'Ford wires its electric trucks for business customers'],
#  ['TSLA',
#   'May-19-21',
#   '09:05PM',
#   'Bitcoin Whipsaws Investors With Same-Day Plunge, Rally of 30%'],
#  ['TSLA',
#   'May-19-21',
#   '08:08PM',
#   "UPDATE 2-Australia's top fuel supplier Ampol to spend $77 mln on future fuels"],
#  ['TSLA',
#   'May-19-21',
#   '08:06PM',
#   'What bitcoins collapse could mean for your retirement'],
#  ['TSLA',
#   'May-19-21',
#   '06:01PM',
#   'Can CARZ ETF Gain Despite Mixed Auto Earnings?'],
#  ['TSLA',
#   'May-19-21',
#   '04:40PM',
#   "ARK Invest Stocks To Buy And Watch: 6 Stocks That Cathie Wood's ARK ETFs Own; Tesla Slashes Losses"],
#  ['TSLA',
#   'May-19-21',
#   '04:22PM',
#   'Tesla Loses Nearly $300 Billion in Market Cap Since January'],
#  ['TSLA',
#   'May-19-21',
#   '04:11PM',
#   'Michael Burry is Shorting Tesla and Buying These 10 Stocks Instead'],
#  ['TSLA',
#   'May-19-21',
#   '04:05PM',
#   "Is GM Stock A Buy? General Motors' EV, AV Plans Race Ahead"],
#  ['TSLA',
#   'May-19-21',
#   '04:04PM',
#   'Bitcoin Falls On New Crackdown But Musk Rallies Faithful; Coinbase Knocked Out Briefly'],
#  ['TSLA',
#   'May-19-21',
#   '03:55PM',
#   'Cryptocrash trends on Twitter as plunge in bitcoin leads to dark humor and mockery'],
#  ['TSLA',
#   'May-19-21',
#   '03:37PM',
#   'Elon Musks carbon comments will be changing point for bitcoin: Gryphon CEO'],
#  ['TSLA',
#   'May-19-21',
#   '03:11PM',
#   'Bitcoin Marches Away From Crypto Pack in Show of Resiliency'],
#  ['TSLA',
#   'May-19-21',
#   '02:39PM',
#   'Bearish Option Trade On Tesla Stock Could Yield A 56% Return'],
#  ['TSLA', 'May-19-21', '02:37PM', 'Bitcoin: Buy the Dip?'],
#  ['TSLA',
#   'May-19-21',
#   '01:41PM',
#   'Tesla shares lag as bitcoin plunges on China crackdown'],
#  ['TSLA',
#   'May-19-21',
#   '01:19PM',
#   'Elon Musk jets in to Britain as ministers seek site for new car factory'],
#  ['TSLA',
#   'May-19-21',
#   '01:00PM',
#   'Coinbase IPO Turns Out to Have Been Bad Day to Splurge on Crypto'],
#  ['TSLA',
#   'May-19-21',
#   '12:40PM',
#   'GM and Ford Find New Bulls Who Sees Shares Rising 40%'],
#  ['TSLA',
#   'May-19-21',
#   '12:20PM',
#   'Dow Jones Drops As Stock Market Sells Off Again; Bitcoin Plunges, But Target Soars'],
#  ['TSLA', 'May-19-21', '12:05PM', 'Why Tesla Stock Fell Sharply on Wednesday'],
#  ['TSLA',
#   'May-19-21',
#   '12:03PM',
#   'Diamond hands: What do the emojis that Elon Musk tweeted about crypto crash mean, and what do they have to do with bitcoin?'],
#  ['TSLA',
#   'May-19-21',
#   '11:59AM',
#   'Dow Jones Dives 587 Points As Bitcoin Crashes On These Warnings; Apple, Tesla Sell Off'],
#  ['TSLA',
#   'May-19-21',
#   '11:37AM',
#   'Elon Musks diamond hands Tesla tweet stems crypto price plunge amid dramatic collapse'],
#  ['TSLA',
#   'May-19-21',
#   '11:19AM',
#   "Bitcoin's Musk hangover infects crypto world, Tesla: 'The next microbubble... to get pricked'"],
#  ['TSLA',
#   'May-19-21',
#   '11:14AM',
#   'Elon Musk says Tesla not selling bitcoin despite huge crypto crash'],
#  ['TSLA', 'May-19-21', '11:07AM', 'Musk: Tesla has diamond hands'],
#  ['TSLA',
#   'May-19-21',
#   '10:29AM',
#   'Cathie Wood Buys Tesla Amid Musk Bitcoin Spat, Burry Shorts'],
#  ['TSLA',
#   'May-19-21',
#   '10:05AM',
#   '10 Biggest Companies and Hedge Funds Bullish on Ethereum'],
#  ['TSLA',
#   'May-19-21',
#   '09:00AM',
#   'My Take: 3 Reasons Tesla Investors Should Not Be Worried About "The Big Short" Investor'],
#  ['TSLA',
#   'May-19-21',
#   '08:57AM',
#   'China Bars Financial Companies From Cryptocurrency Services'],
#  ['TSLA',
#   'May-19-21',
#   '08:45AM',
#   "Here's Why Betting Against Tesla Stock May Not Be Wise"],
#  ['TSLA',
#   'May-19-21',
#   '08:26AM',
#   'Dow Jones Futures Signal Sharp Losses For Market Rally As Bitcoin Crashes; More Bad Tesla News But Target Earnings Strong'],
#  ['TSLA',
#   'May-19-21',
#   '07:24AM',
#   'Worried About Crypto Energy Use? Check Out These Clean Energy Plays'],
#  ['TSLA',
#   'May-19-21',
#   '07:06AM',
#   'No pain, no gain for big funds hunting the next Tesla'],
#  ['TSLA',
#   'May-19-21',
#   '07:00AM',
#   'INSIGHT-No pain, no gain for big funds hunting the next Tesla'],
#  ['TSLA',
#   'May-19-21',
#   '04:22AM',
#   "Bitcoin Plummets Amid Crypto Rout: Jim Cramer Says 'Accept The Beatdown'"],
#  ['TSLA',
#   'May-19-21',
#   '04:03AM',
#   'Cryptocurrency prices continue to tumble as bitcoin falls below $40,000'],
#  ['TSLA',
#   'May-19-21',
#   '03:47AM',
#   "UPDATE 3-Bitcoin slides below $40,000 after China's new crypto ban"],
#  ['TSLA',
#   'May-19-21',
#   '02:46AM',
#   'Tesla Slips as China New-Vehicle Registrations Downshift Dramatically'],
#  ['TSLA',
#   'May-19-21',
#   '01:06AM',
#   "Bitcoin slides below $40,000 after China's new crypto curbs"],
#  ['TSLA',
#   'May-19-21',
#   '01:04AM',
#   'Bitcoins Obstacles Mount Amid China Cryptocurrency Warning'],
#  ['TSLA',
#   'May-18-21',
#   '07:01PM',
#   "UK has 'mountain to climb' to hit car emission target, MPs warn"],
#  ['TSLA',
#   'May-18-21',
#   '05:30PM',
#   "Tesla already 'biggest short in the market' as Burry piles on: S3 Partners"],
#  ['TSLA',
#   'May-18-21',
#   '05:20PM',
#   'Is Ford Stock A Buy Now Amid Biden EV Push? Chip Shortage Tests Auto Giant But Earnings Turning Around'],
#  ['TSLA',
#   'May-18-21',
#   '04:28PM',
#   'Big Short investor Michael Burry, who was portrayed by Christian Bale, bets against Tesla'],
#  ['TSLA',
#   'May-18-21',
#   '04:17PM',
#   'Tesla Starts to Recover After Breaching Key Technical Level'],
#  ['TSLA',
#   'May-18-21',
#   '04:15PM',
#   "Tesla Eyes 'Nightmare' While EV Startups Lordstown, Fisker Jump"],
#  ['TSLA',
#   'May-18-21',
#   '02:21PM',
#   "UPDATE 3-Burry of 'Big Short' fame reveals large bearish bet against Tesla"],
#  ['TSLA',
#   'May-18-21',
#   '02:08PM',
#   'Why is crypto SafeMoon trending, and why is Dave Portnoy using it to diversify his bitcoin exposure?'],
#  ['TSLA',
#   'May-18-21',
#   '01:29PM',
#   'Bitcoin Falls to a 3-Month Low. Should You Buy on the Dip?'],
#  ['TSLA',
#   'May-18-21',
#   '01:28PM',
#   'Tesla Stock Is Getting Shorted Again. Why It Could Be Time to Buy.'],
#  ['TSLA',
#   'May-18-21',
#   '01:09PM',
#   'These Are The 5 Best EV Stocks To Buy And Watch Now'],
#  ['TSLA',
#   'May-18-21',
#   '12:19PM',
#   'Stock Market Mixed As Nasdaq Leads, Dow Jones Lags; How Did These 2 Dow Stocks Fare?'],
#  ['TSLA',
#   'May-18-21',
#   '12:10PM',
#   'California DMV Probes Tesla Over Self-Driving Claims'],
#  ['TSLA',
#   'May-18-21',
#   '11:44AM',
#   'Teslas India market will be just as big as China: Analyst'],
#  ['TSLA',
#   'May-18-21',
#   '11:44AM',
#   'Bitcoin Backers Now Have to Worry About Key Man Risk With Elon Musk'],
#  ['TSLA',
#   'May-18-21',
#   '11:22AM',
#   'Lamborghini unveils 1.5bn plan to make all cars hybrid electric by 2024'],
#  ['TSLA', 'May-18-21', '10:49AM', 'Even Lamborghini Is Getting Into EVs'],
#  ['TSLA',
#   'May-18-21',
#   '10:44AM',
#   'US STOCKS-S&P 500, Dow slip as telecom stocks eclipse upbeat results from retailers'],
#  ['TSLA',
#   'May-18-21',
#   '10:16AM',
#   'Ford set to reveal F-150 Lightning electric pick-up truck'],
#  ['TSLA',
#   'May-18-21',
#   '10:16AM',
#   'May 24 at 2PM ET: Fireside Chat with Origin Materials to Discuss Merger with Artius Acquisition Inc.'],
#  ['TSLA',
#   'May-18-21',
#   '10:13AM',
#   "Is Tesla Stock A Buy Right Now? Here's What Tesla Earnings, Charts Show"],
#  ['TSLA',
#   'May-18-21',
#   '10:12AM',
#   "Tesla is the 'biggest short in the market': strategist"],
#  ['TSLA', 'May-18-21', '10:05AM', '10 Best Blockchain Stocks to Buy'],
#  ['TSLA',
#   'May-18-21',
#   '10:03AM',
#   'Cryptocurrency scammers disguise themselves as Elon Musk to steal millions of dollars'],
#  ['TSLA',
#   'May-18-21',
#   '08:37AM',
#   'US STOCKS-Wall St set for higher open after Walmart, Home Depot results beat'],
#  ['TSLA',
#   'May-18-21',
#   '08:28AM',
#   'Bitcoin, Bitcoin Stocks Like Coinbase Tumble On Elon Musk Tweets; Tesla Breaks Key Level'],
#  ['TSLA',
#   'May-18-21',
#   '08:00AM',
#   'Dow Jones Futures Rally As Tesla Gives Up Key Level; Baidu Jumps On Earnings'],
#  ['TSLA',
#   'May-18-21',
#   '06:47AM',
#   'Facebook to Launch Diem Cryptocurrency Amid Rising Digitalization'],
#  ['TSLA',
#   'May-18-21',
#   '06:47AM',
#   'What is Cardano? The green crypto that defied Musks bitcoin crash  and hopes to surpass Facebook and Netflix'],
#  ['TSLA',
#   'May-18-21',
#   '06:31AM',
#   'Which Electric Vehicle Stocks Could Produce 10X Returns?'],
#  ['TSLA', 'May-18-21', '06:15AM', '3 No-Brainer Buys When the Market Crashes'],
#  ['TSLA',
#   'May-18-21',
#   '06:00AM',
#   "Rivian's Tesla Alums Lead Charge as Debut Nears for First Three EVs"],
#  ['TSLA',
#   'May-18-21',
#   '05:34AM',
#   'Bitcoin Extends Slide After China Issues Stark Virtual Currency Warning'],
#  ['TSLA',
#   'May-18-21',
#   '05:29AM',
#   'Tesla cooperating with Chinese authorities after accident killed police officer'],
#  ['TSLA',
#   'May-18-21',
#   '05:25AM',
#   'Tesla cooperating with Chinese authorities after accident killed police officer'],
#  ['TSLA',
#   'May-18-21',
#   '04:38AM',
#   'Big Short investor Michael Burry makes bearish bet on Tesla'],
#  ['TSLA',
#   'May-18-21',
#   '04:37AM',
#   "Bitcoin stabilises as Musk backlash spawns new crypto 'stopelon'"],
#  ['TSLA',
#   'May-18-21',
#   '03:24AM',
#   'Elon Musk loses ranking as worlds second-richest person as Tesla value drops'],
#  ['TSLA',
#   'May-18-21',
#   '03:18AM',
#   'Bitcoin price  live: Crypto recovers slightly after Elon Musk sends BTC and other coins plunging'],
#  ['TSLA',
#   'May-17-21',
#   '11:28PM',
#   'Toyota Motor powers to record high with cyclical shares back in demand'],
#  ['TSLA',
#   'May-17-21',
#   '09:13PM',
#   "Bitcoin loses its star supporter after Elon Musk's change of heart"],
#  ['TSLA',
#   'May-17-21',
#   '09:04PM',
#   'California DMV places Teslas Full Self-Driving under review'],
#  ['TSLA',
#   'May-17-21',
#   '08:35PM',
#   'Burry of Big Short Fame Places Big Bet Against Musk, Tesla'],
#  ['GOOG',
#   'May-20-21',
#   '08:12AM',
#   'Dow Jones Futures Fall As Stock Market Rally Test Continues, Bitcoin Rebounds; Target, Facebook, Google In Buy Zones'],
#  ['GOOG',
#   'May-20-21',
#   '07:05AM',
#   'Why the future for Microsoft, Amazon, Google, Apple and other pricey growth stocks isnt so bright'],
#  ['GOOG',
#   'May-20-21',
#   '07:00AM',
#   'Blockbusters like Godzilla v. Kong help all of us in the movie business: Jane Rosenthal'],
#  ['GOOG',
#   'May-20-21',
#   '06:36AM',
#   'UPDATE 1-Google appeals court order to unblock YouTube account of sanctioned businessman'],
#  ['GOOG',
#   'May-20-21',
#   '06:07AM',
#   'Google appeals court order to unblock YouTube account of sanctioned businessman'],
#  ['GOOG',
#   'May-20-21',
#   '06:01AM',
#   'Google appeals court order to unblock YouTube account of sanctioned businessman'],
#  ['GOOG',
#   'May-20-21',
#   '06:00AM',
#   'Influencers with Andy Serwer: Jane Rosenthal'],
#  ['GOOG',
#   'May-20-21',
#   '05:47AM',
#   '10 Best Dividend Stocks to Buy According to Billionaire Richard Chilton'],
#  ['GOOG', 'May-19-21', '08:00PM', 'Online fraud: lets close the loopholes'],
#  ['GOOG', 'May-19-21', '06:27PM', 'Marriott Had Good News to Report'],
#  ['GOOG',
#   'May-19-21',
#   '05:29PM',
#   'Google is making search worse by making it easier'],
#  ['GOOG',
#   'May-19-21',
#   '04:59PM',
#   'Waymo Eyes Raising Up to $4 Billion as Leaders Exits Sow Doubts'],
#  ['GOOG',
#   'May-19-21',
#   '04:11PM',
#   'Michael Burry is Shorting Tesla and Buying These 10 Stocks Instead'],
#  ['GOOG',
#   'May-19-21',
#   '03:56PM',
#   "We're lacking a positive catalyst in the market: Sevens Report Research President"],
#  ['GOOG',
#   'May-19-21',
#   '03:40PM',
#   'EU Legislator Advocates User Privacy Rights Under EU Tech Rules: Reuters'],
#  ['GOOG',
#   'May-19-21',
#   '01:39PM',
#   'Exclusive - EU wants firm pledges from tech giants in fake news fight'],
#  ['GOOG',
#   'May-19-21',
#   '12:19PM',
#   '8 best home routers: Boost the speed of your internet connection'],
#  ['GOOG',
#   'May-19-21',
#   '12:08PM',
#   'Is Shopify Stock A Buy After Blowout Earnings Report?'],
#  ['GOOG',
#   'May-19-21',
#   '11:17AM',
#   '11 best smart speakers for virtual assistance at home and on the go'],
#  ['GOOG',
#   'May-19-21',
#   '10:50AM',
#   'Why women should go for top jobs and leadership roles'],
#  ['GOOG',
#   'May-19-21',
#   '10:19AM',
#   'EU lawmaker wants stronger privacy rights in proposed EU tech rules'],
#  ['GOOG',
#   'May-19-21',
#   '10:14AM',
#   'Alphabet Expands Its Shopify E-commerce Partnership'],
#  ['GOOG',
#   'May-19-21',
#   '10:09AM',
#   'Is Salesforce Stock A Buy? Digital Transformation Powerhouse Struggles Amid Slack Deal'],
#  ['GOOG',
#   'May-19-21',
#   '10:05AM',
#   '10 Biggest Companies and Hedge Funds Bullish on Ethereum'],
#  ['GOOG',
#   'May-19-21',
#   '10:00AM',
#   'Are the FAANG Stocks Still Good Buys Today?'],
#  ['GOOG',
#   'May-19-21',
#   '09:30AM',
#   'Movie theater experience has to reinvent itself: Jane Rosenthal'],
#  ['GOOG',
#   'May-19-21',
#   '09:00AM',
#   "Apple's iPad Pro is the closest its come to replacing the laptop"],
#  ['GOOG',
#   'May-19-21',
#   '08:50AM',
#   'Google I/O: Wear OS, Android, Shopping, Holograms and More'],
#  ['GOOG',
#   'May-19-21',
#   '08:15AM',
#   'Down 40%, Is Now the Time to Buy Spotify Stock?'],
#  ['GOOG',
#   'May-19-21',
#   '07:57AM',
#   '5 Stocks to Make the Most of Smart Home Market Growth'],
#  ['GOOG',
#   'May-19-21',
#   '07:10AM',
#   'Tech Market Crash: 3 Best Growth Stocks to Buy Now'],
#  ['GOOG',
#   'May-19-21',
#   '06:16AM',
#   'Google develops AI tool to help diagnose skin conditions'],
#  ['GOOG',
#   'May-19-21',
#   '06:00AM',
#   "Burger King aims to take chicken sandwich crown with new 'Ch'King'"],
#  ['GOOG',
#   'May-19-21',
#   '02:04AM',
#   'Jewish Google employees call for company to support Palestinians amid Israels bombing of Gaza'],
#  ['GOOG',
#   'May-18-21',
#   '08:41PM',
#   'Canada says reiterated to U.S. that it plans a digital services tax - minister'],
#  ['GOOG',
#   'May-18-21',
#   '07:13PM',
#   'Epic Tries to Show Apple Is Antitrust Violator Beyond App Store'],
#  ['GOOG',
#   'May-18-21',
#   '06:38PM',
#   'Pinterest Promises More Gender, Racial Diverse Workforce: WSJ'],
#  ['GOOG',
#   'May-18-21',
#   '05:46PM',
#   'Google Debuts Shopping Graph, Machine Learning Tool to Make AI Easier'],
#  ['GOOG',
#   'May-18-21',
#   '05:10PM',
#   'Dow Jones Futures: Stock Market Rally Below Key Levels, Bitcoin Near Lows; More Bad Tesla News, These Old Winners Still Look Weak'],
#  ['GOOG',
#   'May-18-21',
#   '05:10PM',
#   'Google Puts Tools Rivaling Microsoft, Slack at Center of I/O'],
#  ['GOOG',
#   'May-18-21',
#   '04:05PM',
#   'Google Launches News Showcase News In India'],
#  ['GOOG',
#   'May-18-21',
#   '03:37PM',
#   "Google is making big design and privacy changes to the world's most popular operating system"],
#  ['GOOG',
#   'May-18-21',
#   '03:35PM',
#   'Google Backtracks on Office Returns: Will Other Companies Follow?'],
#  ['GOOG',
#   'May-18-21',
#   '03:28PM',
#   'Amazon Extends Pause on Police Use of Facial Recognition Tech'],
#  ['GOOG',
#   'May-18-21',
#   '03:25PM',
#   'Google Docs to prompt users to write in gender-free language'],
#  ['GOOG',
#   'May-18-21',
#   '03:04PM',
#   'Google is teaming up with Samsung to take on the Apple Watch'],
#  ['GOOG',
#   'May-18-21',
#   '03:01PM',
#   'Shopify Merchants Will Be Showcased on Googles Shopping Site'],
#  ['GOOG',
#   'May-18-21',
#   '02:19PM',
#   'Google announces a host of updates to Android, search and other features as part of I/O event'],
#  ['GOOG',
#   'May-18-21',
#   '02:16PM',
#   'Google Adds Feature to Zap Recent Search History in Privacy Push'],
#  ['GOOG',
#   'May-18-21',
#   '01:40PM',
#   'UPDATE 2-Slate of Google updates boost its smartwatch, work collaboration efforts'],
#  ['GOOG',
#   'May-18-21',
#   '12:10PM',
#   'California DMV Probes Tesla Over Self-Driving Claims'],
#  ['GOOG',
#   'May-18-21',
#   '11:00AM',
#   'This Top Computer and Technology Stock is a #1 (Strong Buy): Why It Should Be on Your Radar'],
#  ['GOOG',
#   'May-18-21',
#   '11:00AM',
#   'Down 30%, Is The Trade Desk a Screaming Buy?'],
#  ['GOOG',
#   'May-18-21',
#   '08:11AM',
#   'Is Google Stock A Buy? Internet Search Giant Could Finally Be Best FANG Stock In 2021'],
#  ['GOOG',
#   'May-18-21',
#   '06:01AM',
#   'Google lays out new features to keep users clicking after lockdown'],
#  ['GOOG',
#   'May-18-21',
#   '05:42AM',
#   'Alphabets Google Migrates Ilunion to Cloud in Record Time'],
#  ['GOOG',
#   'May-18-21',
#   '03:21AM',
#   'Google ties up with 30 publishers to start news platform in COVID-ravaged India'],
#  ['GOOG',
#   'May-18-21',
#   '03:19AM',
#   'Google ties up with 30 publishers to start news platform in COVID-ravaged India'],
#  ['GOOG',
#   'May-17-21',
#   '11:11PM',
#   'Alibaba Leads $400 Million Investment in Vietnam Retail Firm'],
#  ['GOOG',
#   'May-17-21',
#   '08:00PM',
#   'Big Tech races to clean up act as cloud energy use grows'],
#  ['GOOG',
#   'May-17-21',
#   '04:53PM',
#   'U.S. labor leader calls for human drivers in automated vehicles'],
#  ['GOOG',
#   'May-17-21',
#   '04:44PM',
#   'UPDATE 2-U.S. labor leader calls for human drivers in automated vehicles'],
#  ['GOOG',
#   'May-17-21',
#   '03:54PM',
#   'These Are The Best Robinhood Stocks To Buy Or Watch Now'],
#  ['GOOG',
#   'May-17-21',
#   '02:40PM',
#   'Apple Begins App Store Defense in Epic Antitrust Fight'],
#  ['GOOG',
#   'May-17-21',
#   '02:39PM',
#   "Market volatility to continue through the summer: People's United Advisors CIO"],
#  ['GOOG',
#   'May-17-21',
#   '12:22PM',
#   "UPDATE 1-Parler returns to Apple's App Store, names new CEO"],
#  ['GOOG',
#   'May-17-21',
#   '12:15PM',
#   "Parler returns to Apple's App Store, names new CEO"],
#  ['GOOG',
#   'May-17-21',
#   '12:07PM',
#   'Dow Slips as Wall Street Continues to Back Value Over Growth'],
#  ['GOOG',
#   'May-17-21',
#   '11:39AM',
#   'Google I/O 2021 developer conference will feature Android 12 and maybe a Google watch'],
#  ['GOOG',
#   'May-17-21',
#   '11:30AM',
#   'Is Alphabet (GOOGL) Stock Outpacing Its Computer and Technology Peers This Year?'],
#  ['GOOG',
#   'May-17-21',
#   '11:30AM',
#   'Is Alphabet (GOOG) Stock Outpacing Its Computer and Technology Peers This Year?'],
#  ['GOOG',
#   'May-17-21',
#   '10:44AM',
#   'Bragar Eagel & Squire is Investigating Certain Officers and Directors of XL Fleet, Zoom, Capital One, and Alphabet on Behalf of Long-Term Stockholders and Encourages Investors to Contact the Firm'],
#  ['GOOG',
#   'May-17-21',
#   '09:31AM',
#   'Dow Eases From Lows, But Remains Under Pressure as Tech Bleeds'],
#  ['GOOG',
#   'May-17-21',
#   '09:00AM',
#   'Microsoft is extending its Teams app to regular consumers'],
#  ['GOOG', 'May-17-21', '08:55AM', '10 Best AI Stocks under $50'],
#  ['GOOG',
#   'May-17-21',
#   '08:23AM',
#   'France embraces Google, Microsoft in quest to safeguard sensitive data'],
#  ['GOOG',
#   'May-17-21',
#   '08:19AM',
#   'Dow Jones Futures Fall In Still-Tricky Market, But ASML, Google Flash Buys; Bitcoin Dives On Latest Musk Tweets'],
#  ['GOOG',
#   'May-17-21',
#   '06:05AM',
#   'Gojek to Merge With Tokopedia to Create Indonesia Tech Giant'],
#  ['GOOG',
#   'May-16-21',
#   '08:00PM',
#   'Critics raise alarm over Big Techs most powerful tools'],
#  ['GOOG',
#   'May-16-21',
#   '12:18PM',
#   'Revealed: The areas in the UK with the highest financial literacy'],
#  ['GOOG',
#   'May-16-21',
#   '06:06AM',
#   'Ignore Dogecoin: These Stocks Will Make You Rich'],
#  ['GOOG',
#   'May-15-21',
#   '08:00PM',
#   'UK online harms bill misses frauds gateway'],
#  ['GOOG', 'May-15-21', '05:56PM', 'Should You HODL Bitcoin?'],
#  ['GOOG',
#   'May-15-21',
#   '08:00AM',
#   "One Of The Best Mutual Fund's Bets On Economic Reopening"],
#  ['GOOG', 'May-15-21', '07:31AM', "Elon Musk's Best Investments"],
#  ['GOOG',
#   'May-15-21',
#   '04:00AM',
#   'Tech Stocks Roundup: Jim Cramer Says to Hold Onto FAANG Stocks'],
#  ['GOOG',
#   'May-14-21',
#   '07:46PM',
#   'Fired Engineer Says Apple Was Previously Aware of His Writing'],
#  ['GOOG',
#   'May-14-21',
#   '06:00PM',
#   'Two Tech Firms, Together Worth $1.8 Trillion, Join The Long-Term Leaders'],
#  ['GOOG',
#   'May-14-21',
#   '04:17PM',
#   'Dow Jones Gains As Rally Continues; Disney Stock Dives; Google Stock Offers Buy Point'],
#  ['GOOG',
#   'May-14-21',
#   '03:28PM',
#   'California District Judge Dismisses Google Antitrust Lawsuit Brought By Advertiser Group: Reuters'],
#  ['GOOG',
#   'May-14-21',
#   '03:24PM',
#   'US Senators On The Verge Of A $52B Chip Funding Deal Announcement: Reuters'],
#  ['GOOG',
#   'May-14-21',
#   '03:03PM',
#   'Bitcoins reflecting a new dimension of thinking about cryptocurrency: Rayliant Global Advisors CIO'],
#  ['GOOG',
#   'May-14-21',
#   '01:00PM',
#   'Alphabet (GOOG)s Notable Q1 Performance Took a Spot in Polen Capitals Top Contributors List'],
#  ['GOOG',
#   'May-14-21',
#   '12:13PM',
#   'Tech Fights Claim That Foreign-Worker Spouses Help Take Jobs'],
#  ['GOOG',
#   'May-14-21',
#   '11:55AM',
#   "Bird CEO on micromobility industry: 'the future is electrified transportation'"],
#  ['GOOG', 'May-14-21', '11:24AM', 'Google Rebounds Bullishly'],
#  ['GOOG',
#   'May-14-21',
#   '09:57AM',
#   'S&P 500 Racks Up Gains as Tech Turnaround Continues After Recent Rout'],
#  ['GOOG',
#   'May-14-21',
#   '09:18AM',
#   'Alphabet (GOOGL) Boosts Google Pay Reach With New Feature'],
#  ['GOOG',
#   'May-14-21',
#   '08:21AM',
#   'Zoom Video Rebounds From Recent Drop; Mizuho Bullish'],
#  ['GOOG',
#   'May-14-21',
#   '08:00AM',
#   'Here Are The Leaders In Cloud Computing Spending  Maybe']]

# %% [markdown]
# **Sentiment Analysis with Vader**

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head()
# Out:
#   ticker        date     time  ...    neu    pos  compound
# 0   AMZN  2021-05-20  08:30AM  ...  0.732  0.000   -0.2960
# 1   AMZN  2021-05-20  08:03AM  ...  1.000  0.000    0.0000
# 2   AMZN  2021-05-20  07:14AM  ...  1.000  0.000    0.0000
# 3   AMZN  2021-05-20  07:00AM  ...  0.714  0.286    0.6369
# 4   AMZN  2021-05-20  07:00AM  ...  0.769  0.231    0.4019
#
# [5 rows x 8 columns]

# %% [markdown]
# Plot a Bar Chart of the Sentiment Score for Each Day

# %%
plt.rcParams['figure.figsize'] = [10, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind = 'bar')
plt.grid()
